# %%
import pandas as pd
import glob

# %%
pd.set_option('display.max_rows', 200)

# %%
sub_df=pd.read_csv('2021q2/sub.txt',sep='\t', header=0)
tag_df=pd.read_csv('2021q2/tag.txt',sep='\t', header=0)
num_df=pd.read_csv('2021q2/num.txt',sep='\t', header=0)
pre_df=pd.read_csv('2021q2/pre.txt',sep='\t', header=0)

# %%
#files = glob.glob("2021q1/*.txt")

# %%
#for f in files:
    #tsv = pd.read_csv(f,sep='\t',header=0)

# %%
# sub_df

# %%
sub_df=sub_df.append(pd.read_csv('2021q1/sub.txt',sep='\t', header=0))
tag_df=tag_df.append(pd.read_csv('2021q1/tag.txt',sep='\t', header=0))
num_df=num_df.append(pd.read_csv('2021q1/num.txt',sep='\t', header=0))
pre_df=pre_df.append(pd.read_csv('2021q1/pre.txt',sep='\t', header=0))

# %%
# sub_df

# %%
sub_df=sub_df.append(pd.read_csv('2020q4/sub.txt',sep='\t', header=0))
tag_df=tag_df.append(pd.read_csv('2020q4/tag.txt',sep='\t', header=0))
num_df=num_df.append(pd.read_csv('2020q4/num.txt',sep='\t', header=0))
pre_df=pre_df.append(pd.read_csv('2020q4/pre.txt',sep='\t', header=0))

# %%
sub_df=sub_df.append(pd.read_csv('2020q3/sub.txt',sep='\t', header=0))
tag_df=tag_df.append(pd.read_csv('2020q3/tag.txt',sep='\t', header=0))
num_df=num_df.append(pd.read_csv('2020q3/num.txt',sep='\t', header=0))
pre_df=pre_df.append(pd.read_csv('2020q3/pre.txt',sep='\t', header=0))

# %%
sub_df=sub_df.append(pd.read_csv('2020q2/sub.txt',sep='\t', header=0))
tag_df=tag_df.append(pd.read_csv('2020q2/tag.txt',sep='\t', header=0))
num_df=num_df.append(pd.read_csv('2020q2/num.txt',sep='\t', header=0))
pre_df=pre_df.append(pd.read_csv('2020q2/pre.txt',sep='\t', header=0))
# Out:
# C:\Users\Mighel\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
sub_df=sub_df.append(pd.read_csv('2020q1/sub.txt',sep='\t', header=0))
tag_df=tag_df.append(pd.read_csv('2020q1/tag.txt',sep='\t', header=0))
num_df=num_df.append(pd.read_csv('2020q1/num.txt',sep='\t', header=0))
pre_df=pre_df.append(pd.read_csv('2020q1/pre.txt',sep='\t', header=0))

# %%
sub_df=sub_df.append(pd.read_csv('2019q4/sub.txt',sep='\t', header=0))
tag_df=tag_df.append(pd.read_csv('2019q4/tag.txt',sep='\t', header=0))
num_df=num_df.append(pd.read_csv('2019q4/num.txt',sep='\t', header=0))
pre_df=pre_df.append(pd.read_csv('2019q4/pre.txt',sep='\t', header=0))

# %%
sub_df=sub_df.append(pd.read_csv('2019q3/sub.txt',sep='\t', header=0))
tag_df=tag_df.append(pd.read_csv('2019q3/tag.txt',sep='\t', header=0))
num_df=num_df.append(pd.read_csv('2019q3/num.txt',sep='\t', header=0))
pre_df=pre_df.append(pd.read_csv('2019q3/pre.txt',sep='\t', header=0))

# %%
sub_df=sub_df.append(pd.read_csv('2019q2/sub.txt',sep='\t', header=0))
tag_df=tag_df.append(pd.read_csv('2019q2/tag.txt',sep='\t', header=0))
num_df=num_df.append(pd.read_csv('2019q2/num.txt',sep='\t', header=0))
pre_df=pre_df.append(pd.read_csv('2019q2/pre.txt',sep='\t', header=0))

# %%
sub_df=sub_df.append(pd.read_csv('2019q1/sub.txt',sep='\t', header=0))
tag_df=tag_df.append(pd.read_csv('2019q1/tag.txt',sep='\t', header=0))
num_df=num_df.append(pd.read_csv('2019q1/num.txt',sep='\t', header=0))
pre_df=pre_df.append(pd.read_csv('2019q1/pre.txt',sep='\t', header=0))

# %%
sub_df=sub_df.append(pd.read_csv('2018q4/sub.txt',sep='\t', header=0))
tag_df=tag_df.append(pd.read_csv('2018q4/tag.txt',sep='\t', header=0))
num_df=num_df.append(pd.read_csv('2018q4/num.txt',sep='\t', header=0))
pre_df=pre_df.append(pd.read_csv('2018q4/pre.txt',sep='\t', header=0))

# %%
sub_df=sub_df.append(pd.read_csv('2018q3/sub.txt',sep='\t', header=0))
tag_df=tag_df.append(pd.read_csv('2018q3/tag.txt',sep='\t', header=0))
num_df=num_df.append(pd.read_csv('2018q3/num.txt',sep='\t', header=0))
pre_df=pre_df.append(pd.read_csv('2018q3/pre.txt',sep='\t', header=0))

# %%
sub_df=sub_df.append(pd.read_csv('2018q2/sub.txt',sep='\t', header=0))
tag_df=tag_df.append(pd.read_csv('2018q2/tag.txt',sep='\t', header=0))
num_df=num_df.append(pd.read_csv('2018q2/num.txt',sep='\t', header=0))
pre_df=pre_df.append(pd.read_csv('2018q2/pre.txt',sep='\t', header=0))

# %%
sub_df=sub_df.append(pd.read_csv('2018q1/sub.txt',sep='\t', header=0))
tag_df=tag_df.append(pd.read_csv('2018q1/tag.txt',sep='\t', header=0))
num_df=num_df.append(pd.read_csv('2018q1/num.txt',sep='\t', header=0))
pre_df=pre_df.append(pd.read_csv('2018q1/pre.txt',sep='\t', header=0))

# %%
# tag_df

# %%
# num_df

# %%
# pre_df

# %%
num_pre_df = pd.merge(num_df, pre_df,  on=['adsh','tag','version'])

# %%
# num_pre_df

# %%
num_pre_sub_df = pd.merge(num_pre_df, sub_df,  how='left', on='adsh')

# %% [markdown]
# num_pre_sub_df.columns

# %%
# num_pre_sub_df.columns

# %%
# num_pre_sub_df

# %%
ex_value = num_pre_sub_df.groupby("tag").size()

# %%
ex_value
# Out:
# tag
# A10DebtSettlementsIncludingRelatedCosts                      6
# A2017ConvertibleSubordiantedDebt                             2
# A2018ConvertibleSubordinatedDebt                            10
# A2023NotesEquityIssuanceCosts                               14
# A2024NoteEquityimpact                                        4
#                                                             ..
# wuc_AblationIntellectualProperty                             2
# wuc_IncreaseDecreaseInWarrantModificationExpenses            2
# wuc_SaleOf192278UnitsOnJune172019InPrivatePlacement          1
# wuc_StockDuringPeriodOfWarrantModificationExpense            1
# wuc_StockIssuedDuringPeriodSaleOfUnitsInPrivatePlacement     1
# Length: 158156, dtype: int64

# %%
num_pre_sub_df=num_pre_sub_df[(num_pre_sub_df['form']=='10-Q')]

# %%
# num_pre_sub_df

# %%
# num_pre_sub_df.columns

# %%
test_df=num_pre_sub_df[['adsh', 'form', 'report','line','tag', 'cik', 'name', 'version', 'ddate', 'qtrs', 'uom', 'value',
     'stmt','plabel','afs', 'wksi', 'fye', 'period', 'fy', 'fp']]

# %%
# test_df

# %%
# num_pre_sub_df[(num_pre_sub_df['tag']=='NetCashProvidedByUsedInOperatingActivities')]

# %%
test_df['tag'].value_counts()
# Out:
# NetIncomeLoss                                                                 522874
# StockholdersEquity                                                            495073
# CashAndCashEquivalentsAtCarryingValue                                         347102
# CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents                 232818
# ProfitLoss                                                                    231838
#                                                                                ...
# NoncashOrPartNoncashAcquisitionCashSurrenderValueOfLifeInsuranceAcquired           1
# AdjustmentsToAdditionalPaidInCapitalInitialValueOfPublicWarrantLiabilities         1
# CashReceivedFromReverseRecapitalization                                            1
# CommonStockValueSurrenderedForTaxWithholdings                                      1
# IncreaseDecreaseInNetIncomeLoss                                                    1
# Name: tag, Length: 95177, dtype: int64

# %%
total_tags=test_df['tag'].value_counts().head(200)

# %%
total_tags.to_csv('total_tags.csv')

# %%
tag_list=['NetCashProvidedByUsedInOperatingActivities',
    'NetCashProvidedByUsedInInvestingActivities',
    'ComprehensiveIncomeNetOfTax',
    'Revenues',
          'DepreciationAndAmortization',
          'RevenueFromContractWithCustomerExcludingAssessedTax',
          'DepreciationDepletionAndAmortization',
         'PropertyPlantAndEquipmentNet',
         'OperatingIncomeLoss']

# %%
tag_list
# Out:
# ['NetCashProvidedByUsedInOperatingActivities',
#  'NetCashProvidedByUsedInInvestingActivities',
#  'ComprehensiveIncomeNetOfTax',
#  'Revenues',
#  'DepreciationAndAmortization',
#  'RevenueFromContractWithCustomerExcludingAssessedTax',
#  'DepreciationDepletionAndAmortization',
#  'PropertyPlantAndEquipmentNet',
#  'OperatingIncomeLoss']

# %%
filtered_df = test_df[test_df['tag'].isin(tag_list)]

# %%
filtered_df
# Out:
#                           adsh  form  report  line  \
# 20350     0000866368-21-000017  10-Q       7    17
# 20351     0000866368-21-000017  10-Q       7    17
# 20352     0001104659-21-056653  10-Q       6    19
# 20353     0001104659-21-056653  10-Q       6    19
# 20354     0001165002-21-000044  10-Q       7    27
# ...                        ...   ...     ...   ...
# 24998209  0001493152-18-004277  10-Q       2    15
# 24999895  0001493152-18-004277  10-Q       4     4
# 24999896  0001493152-18-004277  10-Q       4     4
# 24999897  0001493152-18-004277  10-Q       4     4
# 24999898  0001493152-18-004277  10-Q       4     4
#
#                                                  tag      cik  \
# 20350     NetCashProvidedByUsedInInvestingActivities   866368
# 20351     NetCashProvidedByUsedInInvestingActivities   866368
# 20352     NetCashProvidedByUsedInInvestingActivities  1158324
# 20353     NetCashProvidedByUsedInInvestingActivities  1158324
# 20354     NetCashProvidedByUsedInInvestingActivities  1165002
# ...                                              ...      ...
# 24998209                PropertyPlantAndEquipmentNet  1085243
# 24999895                                    Revenues  1085243
# 24999896                                    Revenues  1085243
# 24999897                                    Revenues  1085243
# 24999898                                    Revenues  1085243
#
#                                           name       version     ddate  qtrs  \
# 20350                 PS BUSINESS PARKS INC/CA  us-gaap/2019  20200331     1
# 20351                 PS BUSINESS PARKS INC/CA  us-gaap/2019  20210331     1
# 20352     COGENT COMMUNICATIONS HOLDINGS, INC.  us-gaap/2019  20200331     1
# 20353     COGENT COMMUNICATIONS HOLDINGS, INC.  us-gaap/2019  20210331     1
# 20354              WESTWOOD HOLDINGS GROUP INC  us-gaap/2019  20210331     1
# ...                                        ...           ...       ...   ...
# 24998209                           VIRTRA, INC  us-gaap/2017  20170930     0
# 24999895                           VIRTRA, INC  us-gaap/2017  20160930     1
# 24999896                           VIRTRA, INC  us-gaap/2017  20160930     3
# 24999897                           VIRTRA, INC  us-gaap/2017  20170930     1
# 24999898                           VIRTRA, INC  us-gaap/2017  20170930     3
#
#           uom       value stmt  \
# 20350     USD   7587000.0   CF
# 20351     USD -16424000.0   CF
# 20352     USD -12866000.0   CF
# 20353     USD -15444000.0   CF
# 20354     USD   9735000.0   CF
# ...       ...         ...  ...
# 24998209  USD    693206.0   BS
# 24999895  USD   3041701.0   IS
# 24999896  USD  12649963.0   IS
# 24999897  USD   4686445.0   IS
# 24999898  USD  14147297.0   IS
#
#                                                      plabel    afs  wksi  \
# 20350     Net cash (used in) provided by investing activ...  1-LAF     0
# 20351     Net cash (used in) provided by investing activ...  1-LAF     0
# 20352                 Net cash used in investing activities  1-LAF     0
# 20353                 Net cash used in investing activities  1-LAF     0
# 20354     Net Cash Provided by (Used in) Investing Activ...  4-NON     0
# ...                                                     ...    ...   ...
# 24998209                        Property and equipment, net  5-SML     0
# 24999895                                      Total revenue  5-SML     0
# 24999896                                      Total revenue  5-SML     0
# 24999897                                      Total revenue  5-SML     0
# 24999898                                      Total revenue  5-SML     0
#
#              fye      period      fy  fp
# 20350     1231.0  20210331.0  2021.0  Q1
# 20351     1231.0  20210331.0  2021.0  Q1
# 20352     1231.0  20210331.0  2021.0  Q1
# 20353     1231.0  20210331.0  2021.0  Q1
# 20354     1231.0  20210331.0  2021.0  Q1
# ...          ...         ...     ...  ..
# 24998209  1231.0  20170930.0  2017.0  Q3
# 24999895  1231.0  20170930.0  2017.0  Q3
# 24999896  1231.0  20170930.0  2017.0  Q3
# 24999897  1231.0  20170930.0  2017.0  Q3
# 24999898  1231.0  20170930.0  2017.0  Q3
#
# [854875 rows x 20 columns]

# %%
# Initialize PyMongo to work with MongoDBs
import pymongo
conn = 'mongodb+srv://admin:admin@cluster0.5lstl.mongodb.net/myFirstDatabase?authSource=admin&replicaSet=atlas-efjkbc-shard-0&w=majority&readPreference=primary&appname=MongoDB%20Compass&retryWrites=true&ssl=true'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.SEC_DB
db.SEC_10Q.drop()

# %%
#Load df into a MongoDB collection
collection = db.SEC_10Q
# Insert collection
#collection.insert_many

# %%
collection.insert_many(filtered_df.to_dict('records'))

# %%
filtered_df.to_csv('sec_10q_2018_2021.csv', index=False)

# %%
test_df.to_csv('sec_10q_2018_2021_full.csv',index=False)

# %%
# Out:
# Empty DataFrame
# Columns: [adsh, form, report, line, tag, cik, name, version, ddate, qtrs, uom, value, stmt, plabel, afs, wksi, fye, period, fy, fp]
# Index: []

# %%
test_df
# Out:
#                           adsh  form  report  line  \
# 0         0001640334-21-000798  10-Q       2     8
# 1         0001640334-21-000798  10-Q       2     8
# 4         0001640334-21-000810  10-Q       2     8
# 5         0001640334-21-000810  10-Q       2     8
# 8         0001477932-21-002141  10-Q       2    10
# ...                        ...   ...     ...   ...
# 25010273  0001440024-18-000031  10-Q       4     3
# 25010274  0001440024-18-000031  10-Q       4     3
# 25010275  0001440024-18-000031  10-Q       4     3
# 25010328  0001440024-18-000027  10-Q       4     3
# 25010329  0001440024-18-000027  10-Q       4     3
#
#                                                   tag      cik  \
# 0         AccountsPayableAndAccruedLiabilitiesCurrent  1593204
# 1         AccountsPayableAndAccruedLiabilitiesCurrent  1593204
# 4         AccountsPayableAndAccruedLiabilitiesCurrent  1584480
# 5         AccountsPayableAndAccruedLiabilitiesCurrent  1584480
# 8         AccountsPayableAndAccruedLiabilitiesCurrent  1631463
# ...                                               ...      ...
# 25010273                 PurchasedTransportationCosts  1440024
# 25010274                 PurchasedTransportationCosts  1440024
# 25010275                 PurchasedTransportationCosts  1440024
# 25010328                 PurchasedTransportationCosts  1440024
# 25010329                 PurchasedTransportationCosts  1440024
#
#                                              name               version  \
# 0                    HUAIZHONG HEALTH GROUP, INC.          us-gaap/2019
# 1                    HUAIZHONG HEALTH GROUP, INC.          us-gaap/2019
# 4                             STARTECH LABS, INC.          us-gaap/2019
# 5                             STARTECH LABS, INC.          us-gaap/2019
# 8                              BARREL ENERGY INC.          us-gaap/2019
# ...                                           ...                   ...
# 25010273  ROADRUNNER TRANSPORTATION SYSTEMS, INC.  0001440024-18-000031
# 25010274  ROADRUNNER TRANSPORTATION SYSTEMS, INC.  0001440024-18-000031
# 25010275  ROADRUNNER TRANSPORTATION SYSTEMS, INC.  0001440024-18-000031
# 25010328  ROADRUNNER TRANSPORTATION SYSTEMS, INC.  0001440024-18-000027
# 25010329  ROADRUNNER TRANSPORTATION SYSTEMS, INC.  0001440024-18-000027
#
#              ddate  qtrs  uom         value stmt  \
# 0         20210131     0  USD  1.001000e+04   BS
# 1         20201031     0  USD  1.091300e+04   BS
# 4         20210228     0  USD  2.974000e+03   BS
# 5         20200531     0  USD  4.225000e+03   BS
# 8         20190930     0  USD  3.157750e+05   BS
# ...            ...   ...  ...           ...  ...
# 25010273  20160930     3  USD  9.819710e+08   IS
# 25010274  20170930     1  USD  3.584800e+08   IS
# 25010275  20170930     3  USD  1.033197e+09   IS
# 25010328  20160331     1  USD  3.080390e+08   IS
# 25010329  20170331     1  USD  3.162850e+08   IS
#
#                                             plabel    afs  wksi     fye  \
# 0         Accounts payable and accrued liabilities  4-NON     0  1031.0
# 1         Accounts payable and accrued liabilities  4-NON     0  1031.0
# 4         Accounts payable and accrued liabilities  4-NON     0   531.0
# 5         Accounts payable and accrued liabilities  4-NON     0   531.0
# 8            Accounts payable and accrued expenses  4-NON     0   930.0
# ...                                            ...    ...   ...     ...
# 25010273            Purchased transportation costs  2-ACC     0  1231.0
# 25010274            Purchased transportation costs  2-ACC     0  1231.0
# 25010275            Purchased transportation costs  2-ACC     0  1231.0
# 25010328            Purchased transportation costs  2-ACC     0  1231.0
# 25010329            Purchased transportation costs  2-ACC     0  1231.0
#
#               period      fy  fp
# 0         20210131.0  2021.0  Q1
# 1         20210131.0  2021.0  Q1
# 4         20210228.0  2021.0  Q3
# 5         20210228.0  2021.0  Q3
# 8         20200331.0  2020.0  Q2
# ...              ...     ...  ..
# 25010273  20170930.0  2017.0  Q3
# 25010274  20170930.0  2017.0  Q3
# 25010275  20170930.0  2017.0  Q3
# 25010328  20170331.0  2017.0  Q1
# 25010329  20170331.0  2017.0  Q1
#
# [14843794 rows x 20 columns]

# %%
aar_df=test_df[(test_df['cik']==1750)]

# %%
aar_df
# Out:
#                           adsh  form  report  line  \
# 1948349   0001104659-21-040394  10-Q       4    24
# 1948350   0001104659-21-040394  10-Q       5     1
# 1948351   0001104659-21-040394  10-Q       4    24
# 1948352   0001104659-21-040394  10-Q       5     1
# 1948353   0001104659-21-040394  10-Q       4    24
# ...                        ...   ...     ...   ...
# 24949964  0001104659-18-019104  10-Q       4    10
# 24949965  0001104659-18-019104  10-Q       4    10
# 24949966  0001104659-18-019104  10-Q       4    10
# 24949967  0001104659-18-019104  10-Q       2    29
# 24949968  0001104659-18-019104  10-Q       2    29
#
#                                                         tag   cik      name  \
# 1948349                                       NetIncomeLoss  1750  AAR CORP
# 1948350                                       NetIncomeLoss  1750  AAR CORP
# 1948351                                       NetIncomeLoss  1750  AAR CORP
# 1948352                                       NetIncomeLoss  1750  AAR CORP
# 1948353                                       NetIncomeLoss  1750  AAR CORP
# ...                                                     ...   ...       ...
# 24949964  OperatingIncomeLossIncludingIncomeLossFromEqui...  1750  AAR CORP
# 24949965  OperatingIncomeLossIncludingIncomeLossFromEqui...  1750  AAR CORP
# 24949966  OperatingIncomeLossIncludingIncomeLossFromEqui...  1750  AAR CORP
# 24949967                  OtherLiabilitiesAndDeferredIncome  1750  AAR CORP
# 24949968                  OtherLiabilitiesAndDeferredIncome  1750  AAR CORP
#
#                        version     ddate  qtrs  uom       value stmt  \
# 1948349           us-gaap/2020  20200229     1  USD   2300000.0   IS
# 1948350           us-gaap/2020  20200229     1  USD   2300000.0   CI
# 1948351           us-gaap/2020  20200229     3  USD  20900000.0   IS
# 1948352           us-gaap/2020  20200229     3  USD  20900000.0   CI
# 1948353           us-gaap/2020  20210228     1  USD  28100000.0   IS
# ...                        ...       ...   ...  ...         ...  ...
# 24949964  0001104659-18-019104  20170228     3  USD  58900000.0   IS
# 24949965  0001104659-18-019104  20180228     1  USD  24200000.0   IS
# 24949966  0001104659-18-019104  20180228     3  USD  63200000.0   IS
# 24949967  0001104659-18-019104  20170531     0  USD  63600000.0   BS
# 24949968  0001104659-18-019104  20180228     0  USD  62400000.0   BS
#
#                                          plabel    afs  wksi    fye  \
# 1948349                              Net income  1-LAF     0  531.0
# 1948350                              Net income  1-LAF     0  531.0
# 1948351                              Net income  1-LAF     0  531.0
# 1948352                              Net income  1-LAF     0  531.0
# 1948353                              Net income  1-LAF     0  531.0
# ...                                         ...    ...   ...    ...
# 24949964                       Operating income  1-LAF     0  531.0
# 24949965                       Operating income  1-LAF     0  531.0
# 24949966                       Operating income  1-LAF     0  531.0
# 24949967  Other liabilities and deferred income  1-LAF     0  531.0
# 24949968  Other liabilities and deferred income  1-LAF     0  531.0
#
#               period      fy  fp
# 1948349   20210228.0  2021.0  Q3
# 1948350   20210228.0  2021.0  Q3
# 1948351   20210228.0  2021.0  Q3
# 1948352   20210228.0  2021.0  Q3
# 1948353   20210228.0  2021.0  Q3
# ...              ...     ...  ..
# 24949964  20180228.0  2018.0  Q3
# 24949965  20180228.0  2018.0  Q3
# 24949966  20180228.0  2018.0  Q3
# 24949967  20180228.0  2018.0  Q3
# 24949968  20180228.0  2018.0  Q3
#
# [2905 rows x 20 columns]

# %%
f=aar_df['tag'].value_counts()

# %%
f
# Out:
# StockholdersEquityIncludingPortionAttributableToNoncontrollingInterest                                                                150
# OtherComprehensiveIncomeLossNetOfTax                                                                                                  100
# ProfitLoss                                                                                                                             92
# CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsIncludingDisposalGroupAndDiscontinuedOperations                           80
# NetIncomeLoss                                                                                                                          68
# IncomeLossFromContinuingOperations                                                                                                     68
# IncomeLossFromDiscontinuedOperationsNetOfTax                                                                                           68
# ProvisionForDoubtfulAccounts                                                                                                           56
# AccumulatedOtherComprehensiveIncomeLossNetOfTax                                                                                        54
# IncomeLossFromContinuingOperationsBeforeIncomeTaxesAndMinorityInterest                                                                 34
# InterestExpense                                                                                                                        34
# ComprehensiveIncomeNetOfTax                                                                                                            34
# IncomeLossFromContinuingOperationsPerBasicShare                                                                                        34
# EarningsPerShareDiluted                                                                                                                34
# CostsAndExpenses                                                                                                                       34
# IncomeTaxExpenseBenefit                                                                                                                34
# DiscontinuedOperationIncomeLossFromDiscontinuedOperationNetOfTaxPerBasicShare                                                          34
# IncomeLossFromContinuingOperationsPerDilutedShare                                                                                      34
# OtherComprehensiveIncomeLossForeignCurrencyTransactionAndTranslationAdjustmentNetOfTax                                                 34
# OperatingIncomeLossIncludingIncomeLossFromEquityMethodInvestments                                                                      34
# EarningsPerShareBasic                                                                                                                  34
# OtherComprehensiveIncomeLossReclassificationAdjustmentFromAOCIPensionAndOtherPostretirementBenefitPlansNetOfTax                        34
# OtherComprehensiveIncomeLossReclassificationAdjustmentFromAOCIPensionAndOtherPostretirementBenefitPlansTax                             34
# DiscontinuedOperationIncomeLossFromDiscontinuedOperationNetOfTaxPerDilutedShare                                                        34
# SellingGeneralAndAdministrativeExpense                                                                                                 34
# StockIssuedDuringPeriodValueStockOptionsExercised                                                                                      33
# RevenueFromContractWithCustomerIncludingAssessedTax                                                                                    30
# DividendsCommonStockCash                                                                                                               30
# InvestmentIncomeInterest                                                                                                               30
# StockIssuedDuringPeriodValueRestrictedStockAwardNetOfForfeitures                                                                       30
# OtherNonoperatingIncomeExpense                                                                                                         27
# CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect                         20
# AdditionalPaidInCapitalCommonStock                                                                                                     20
# EquipmentOnLongTermLease                                                                                                               20
# DeferredIncomeTaxExpenseBenefit                                                                                                        20
# EquipmentOnOrAvailableForShortTermLease                                                                                                20
# OtherAssetsNoncurrent                                                                                                                  20
# ShareBasedCompensation                                                                                                                 20
# AccumulatedDepreciationDepletionAndAmortizationPropertyPlantAndEquipment                                                               20
# OtherAssetsCurrent                                                                                                                     20
# IncreaseDecreaseInAccountsReceivable                                                                                                   20
# NetCashProvidedByUsedInOperatingActivities                                                                                             20
# PaymentsForProceedsFromOtherInvestingActivities                                                                                        20
# DepreciationDepletionAndAmortization                                                                                                   20
# AssetsNoncurrentExcludingPropertyPlantAndEquipment                                                                                     20
# LiabilitiesOfDisposalGroupIncludingDiscontinuedOperationCurrent                                                                        20
# PaymentsToAcquirePropertyPlantAndEquipment                                                                                             20
# CommonStockSharesAuthorized                                                                                                            20
# CommonStockValue                                                                                                                       20
# CashAndCashEquivalentsAtCarryingValue                                                                                                  20
# NetCashProvidedByUsedInOperatingActivitiesContinuingOperations                                                                         20
# CommonStockSharesIssued                                                                                                                20
# IncreaseDecreaseInInventories                                                                                                          20
# PreferredStockSharesIssued                                                                                                             20
# LongTermDebtNoncurrent                                                                                                                 20
# AccruedLiabilitiesCurrent                                                                                                              20
# IncreaseDecreaseInAccountsPayable                                                                                                      20
# CommonStockParOrStatedValuePerShare                                                                                                    20
# LiabilitiesNoncurrent                                                                                                                  20
# AssetsCurrent                                                                                                                          20
# AllowanceForDoubtfulAccountsReceivableCurrent                                                                                          20
# PaymentsOfDividendsCommonStock                                                                                                         20
# RetainedEarningsAccumulatedDeficit                                                                                                     20
# IncreaseDecreaseInOtherOperatingCapitalNet                                                                                             20
# PropertyPlantAndEquipmentNet                                                                                                           20
# LiabilitiesCurrent                                                                                                                     20
# PreferredStockSharesAuthorized                                                                                                         20
# LiabilitiesAndStockholdersEquity                                                                                                       20
# TreasuryStockShares                                                                                                                    20
# CashProvidedByUsedInOperatingActivitiesDiscontinuedOperations                                                                          20
# InventoryNet                                                                                                                           20
# Assets                                                                                                                                 20
# IncreaseDecreaseInEquipmentOnLongTermLease                                                                                             20
# TreasuryStockCommonValue                                                                                                               20
# AccountsPayableCurrent                                                                                                                 20
# PreferredStockParOrStatedValuePerShare                                                                                                 20
# RestrictedCashAndCashEquivalentsAtCarryingValue                                                                                        19
# ContractWithCustomerAssetNetCurrent                                                                                                    18
# NetCashProvidedByUsedInFinancingActivities                                                                                             18
# ProceedsFromRepaymentsOfShortTermDebt                                                                                                  18
# AssetsOfDisposalGroupIncludingDiscontinuedOperation                                                                                    18
# NetCashProvidedByUsedInInvestingActivities                                                                                             18
# PreferredStockValue                                                                                                                    18
# NetCashProvidedByUsedInFinancingActivitiesContinuingOperations                                                                         18
# NetCashProvidedByUsedInInvestingActivitiesContinuingOperations                                                                         18
# AccountsReceivableNetCurrent                                                                                                           16
# OtherLiabilities                                                                                                                       15
# IncreaseDecreaseInContractWithCustomerAsset                                                                                            15
# IncreaseDecreaseInEquipmentOnOrAvailableForShortTermLease                                                                              14
# IntangibleAssetsNetExcludingGoodwill                                                                                                   14
# Goodwill                                                                                                                               14
# FiniteLivedIntangibleAssetsAccumulatedAmortization                                                                                     14
# DeferredRevenueNoncurrent                                                                                                              14
# EffectOfExchangeRateOnCashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsIncludingDisposalGroupAndDiscontinuedOperations     13
# OperatingLeaseRightOfUseAsset                                                                                                          12
# OperatingLeaseLiabilityNoncurrent                                                                                                      12
# IncreaseDecreaseInOtherAccruedLiabilities                                                                                              12
# AllocatedShareBasedCompensationExpenseCredit                                                                                           12
# CashProvidedByUsedInFinancingActivitiesDiscontinuedOperations                                                                          11
# CashProvidedByUsedInInvestingActivitiesDiscontinuedOperations                                                                          11
# PaymentsForRepurchaseOfCommonStock                                                                                                     11
# EntityCommonStockSharesOutstanding                                                                                                     10
# CommonStockDividendsPerShareDeclared                                                                                                   10
# ProceedsFromStockOptionsExercised                                                                                                       8
# IncreaseDecreaseInAccruedLiabilitiesAndTaxesOnIncome                                                                                    8
# IncreaseDecreaseInDeferredRevenue                                                                                                       8
# IncomeLossFromEquityMethodInvestments                                                                                                   8
# PaymentsToAcquireBusinessesNetOfCashAcquired                                                                                            7
# DeferredIncomeTaxLiabilitiesNet                                                                                                         7
# RepaymentsOfLongTermDebt                                                                                                                7
# OtherLiabilitiesAndDeferredIncome                                                                                                       6
# TreasuryStockValueAcquiredCostMethod                                                                                                    6
# GainLossOnSaleOfBusiness                                                                                                                6
# IntangibleAssetsNetIncludingGoodwill                                                                                                    6
# AssetImpairmentCharges                                                                                                                  5
# CostOfGoodsAndServicesSold                                                                                                              5
# CostOfServices                                                                                                                          4
# SalesRevenueServicesNet                                                                                                                 4
# SalesRevenueGoodsNet                                                                                                                    4
# CostOfGoodsSold                                                                                                                         4
# ReceivablesNetCurrent                                                                                                                   4
# SalesRevenueNet                                                                                                                         4
# PaymentsOfFinancingCosts                                                                                                                4
# ProceedsFromPaymentsForOtherFinancingActivities                                                                                         4
# ContractTerminationAndRestructuringCosts                                                                                                3
# ProceedsFromDivestitureOfInterestInJointVenture                                                                                         3
# StockRepurchasedDuringPeriodValue                                                                                                       3
# ProceedsFromIssuanceOfLongTermDebt                                                                                                      3
# ProceedsFromSaleOfProductiveAssets                                                                                                      2
# ProceedsFromShortTermDebt                                                                                                               2
# ProceedsFromLifeInsurancePolicies                                                                                                       2
# LongTermDebtCurrent                                                                                                                     2
# IncreaseDecreaseSocialSecurityTaxEmployerDeferralCaresAct                                                                               2
# OtherExpenses                                                                                                                           2
# SocialSecurityTaxEmployerDeferralCaresAct                                                                                               2
# AssetsOfDisposalGroupIncludingDiscontinuedOperationCurrent                                                                              2
# LossOnContractTermination                                                                                                               1
# GainLossOnDispositionOfAssets1                                                                                                          1
# EffectOfExchangeRateOnCashAndCashEquivalents                                                                                            1
# DisposalGroupIncludingDiscontinuedOperationAssetsNoncurrent                                                                             1
# CustomerContractTerminationAndRestructuringCosts                                                                                        1
# Name: tag, dtype: int64

# %%
filtered_df['tag'].value_counts()
# Out:
# ComprehensiveIncomeNetOfTax                                                  123005
# NetCashProvidedByUsedInOperatingActivities                                   116711
# NetCashProvidedByUsedInInvestingActivities                                   105631
# Revenues                                                                      84509
# DepreciationAndAmortization                                                   50744
# PropertyPlantAndEquipmentGrossPeriodIncreaseDecrease                             89
# NetIncomeLossFromContinuingOperationsAvailableToCommonShareholdersDiluted        26
# Name: tag, dtype: int64

# %%
filt_tags=filtered_df['tag'].value_counts()

# %%
filt_tags.to_csv('filt_tags.csv')

# %%
feature_1_list=['NetCashProvidedByUsedInOperatingActivities','NetCashProvidedByUsedInInvestingActivities']

# %%
feature_1_df = filtered_df[filtered_df['tag'].isin(feature_1_list)]

# %%
feature_1_df
# Out:
#                           adsh  form  report  line  \
# 20350     0000866368-21-000017  10-Q       7    17
# 20351     0000866368-21-000017  10-Q       7    17
# 20352     0001104659-21-056653  10-Q       6    19
# 20353     0001104659-21-056653  10-Q       6    19
# 20354     0001165002-21-000044  10-Q       7    27
# ...                        ...   ...     ...   ...
# 24987350  0001440024-18-000028  10-Q       5    18
# 24987395  0001440024-18-000031  10-Q       5    21
# 24987396  0001440024-18-000031  10-Q       5    21
# 24987408  0001440024-18-000027  10-Q       5    15
# 24987409  0001440024-18-000027  10-Q       5    15
#
#                                                  tag      cik  \
# 20350     NetCashProvidedByUsedInInvestingActivities   866368
# 20351     NetCashProvidedByUsedInInvestingActivities   866368
# 20352     NetCashProvidedByUsedInInvestingActivities  1158324
# 20353     NetCashProvidedByUsedInInvestingActivities  1158324
# 20354     NetCashProvidedByUsedInInvestingActivities  1165002
# ...                                              ...      ...
# 24987350  NetCashProvidedByUsedInOperatingActivities  1440024
# 24987395  NetCashProvidedByUsedInOperatingActivities  1440024
# 24987396  NetCashProvidedByUsedInOperatingActivities  1440024
# 24987408  NetCashProvidedByUsedInOperatingActivities  1440024
# 24987409  NetCashProvidedByUsedInOperatingActivities  1440024
#
#                                              name       version     ddate  \
# 20350                    PS BUSINESS PARKS INC/CA  us-gaap/2019  20200331
# 20351                    PS BUSINESS PARKS INC/CA  us-gaap/2019  20210331
# 20352        COGENT COMMUNICATIONS HOLDINGS, INC.  us-gaap/2019  20200331
# 20353        COGENT COMMUNICATIONS HOLDINGS, INC.  us-gaap/2019  20210331
# 20354                 WESTWOOD HOLDINGS GROUP INC  us-gaap/2019  20210331
# ...                                           ...           ...       ...
# 24987350  ROADRUNNER TRANSPORTATION SYSTEMS, INC.  us-gaap/2017  20170630
# 24987395  ROADRUNNER TRANSPORTATION SYSTEMS, INC.  us-gaap/2017  20160930
# 24987396  ROADRUNNER TRANSPORTATION SYSTEMS, INC.  us-gaap/2017  20170930
# 24987408  ROADRUNNER TRANSPORTATION SYSTEMS, INC.  us-gaap/2017  20160331
# 24987409  ROADRUNNER TRANSPORTATION SYSTEMS, INC.  us-gaap/2017  20170331
#
#           qtrs  uom       value stmt  \
# 20350        1  USD   7587000.0   CF
# 20351        1  USD -16424000.0   CF
# 20352        1  USD -12866000.0   CF
# 20353        1  USD -15444000.0   CF
# 20354        1  USD   9735000.0   CF
# ...        ...  ...         ...  ...
# 24987350     2  USD -39357000.0   CF
# 24987395     3  USD  40355000.0   CF
# 24987396     3  USD -49971000.0   CF
# 24987408     1  USD  23220000.0   CF
# 24987409     1  USD  -7624000.0   CF
#
#                                                      plabel    afs  wksi  \
# 20350     Net cash (used in) provided by investing activ...  1-LAF     0
# 20351     Net cash (used in) provided by investing activ...  1-LAF     0
# 20352                 Net cash used in investing activities  1-LAF     0
# 20353                 Net cash used in investing activities  1-LAF     0
# 20354     Net Cash Provided by (Used in) Investing Activ...  4-NON     0
# ...                                                     ...    ...   ...
# 24987350  Net cash (used in) provided by operating activ...  2-ACC     0
# 24987395  Net cash (used in) provided by operating activ...  2-ACC     0
# 24987396  Net cash (used in) provided by operating activ...  2-ACC     0
# 24987408  Net cash (used in) provided by operating activ...  2-ACC     0
# 24987409  Net cash (used in) provided by operating activ...  2-ACC     0
#
#              fye      period      fy  fp
# 20350     1231.0  20210331.0  2021.0  Q1
# 20351     1231.0  20210331.0  2021.0  Q1
# 20352     1231.0  20210331.0  2021.0  Q1
# 20353     1231.0  20210331.0  2021.0  Q1
# 20354     1231.0  20210331.0  2021.0  Q1
# ...          ...         ...     ...  ..
# 24987350  1231.0  20170630.0  2017.0  Q2
# 24987395  1231.0  20170930.0  2017.0  Q3
# 24987396  1231.0  20170930.0  2017.0  Q3
# 24987408  1231.0  20170331.0  2017.0  Q1
# 24987409  1231.0  20170331.0  2017.0  Q1
#
# [222342 rows x 20 columns]

# %%
test=feature_1_df.sort_values(by=["cik","fy","fp"])

# %%
test[(test['cik']==1750)]
# Out:
#                           adsh  form  report  line  \
# 23200195  0001104659-18-019104  10-Q       7    29
# 23200196  0001104659-18-019104  10-Q       7    29
# 23205169  0001104659-18-019104  10-Q       7    20
# 23205170  0001104659-18-019104  10-Q       7    20
# 20715159  0001104659-18-058911  10-Q       7    26
# 20715160  0001104659-18-058911  10-Q       7    26
# 20722674  0001104659-18-058911  10-Q       7    20
# 20722675  0001104659-18-058911  10-Q       7    20
# 18751621  0001104659-18-073842  10-Q       7    29
# 18751622  0001104659-18-073842  10-Q       7    29
# 18762830  0001104659-18-073842  10-Q       7    21
# 18762831  0001104659-18-073842  10-Q       7    21
# 16823723  0001104659-19-016320  10-Q       7    29
# 16823724  0001104659-19-016320  10-Q       7    29
# 16837494  0001104659-19-016320  10-Q       7    21
# 16837495  0001104659-19-016320  10-Q       7    21
# 13541780  0001410578-19-001436  10-Q       7    27
# 13541781  0001410578-19-001436  10-Q       7    27
# 13543609  0001410578-19-001436  10-Q       7    21
# 13543610  0001410578-19-001436  10-Q       7    21
# 11343607  0001104659-19-074491  10-Q       7    28
# 11343608  0001104659-19-074491  10-Q       7    28
# 11344259  0001104659-19-074491  10-Q       7    21
# 11344260  0001104659-19-074491  10-Q       7    21
# 9353014   0001104659-20-037857  10-Q       7    30
# 9353015   0001104659-20-037857  10-Q       7    30
# 9378294   0001104659-20-037857  10-Q       7    23
# 9378295   0001104659-20-037857  10-Q       7    23
# 5653118   0001104659-20-108360  10-Q       7    36
# 5653119   0001104659-20-108360  10-Q       7    36
# 5661761   0001104659-20-108360  10-Q       7    31
# 5661762   0001104659-20-108360  10-Q       7    31
# 4289476   0001104659-20-137498  10-Q       7    31
# 4289477   0001104659-20-137498  10-Q       7    31
# 4966510   0001104659-20-137498  10-Q       7    37
# 4966511   0001104659-20-137498  10-Q       7    37
# 2271485   0001104659-21-040394  10-Q       7    30
# 2271486   0001104659-21-040394  10-Q       7    30
#
#                                                  tag   cik      name  \
# 23200195  NetCashProvidedByUsedInInvestingActivities  1750  AAR CORP
# 23200196  NetCashProvidedByUsedInInvestingActivities  1750  AAR CORP
# 23205169  NetCashProvidedByUsedInOperatingActivities  1750  AAR CORP
# 23205170  NetCashProvidedByUsedInOperatingActivities  1750  AAR CORP
# 20715159  NetCashProvidedByUsedInInvestingActivities  1750  AAR CORP
# 20715160  NetCashProvidedByUsedInInvestingActivities  1750  AAR CORP
# 20722674  NetCashProvidedByUsedInOperatingActivities  1750  AAR CORP
# 20722675  NetCashProvidedByUsedInOperatingActivities  1750  AAR CORP
# 18751621  NetCashProvidedByUsedInInvestingActivities  1750  AAR CORP
# 18751622  NetCashProvidedByUsedInInvestingActivities  1750  AAR CORP
# 18762830  NetCashProvidedByUsedInOperatingActivities  1750  AAR CORP
# 18762831  NetCashProvidedByUsedInOperatingActivities  1750  AAR CORP
# 16823723  NetCashProvidedByUsedInInvestingActivities  1750  AAR CORP
# 16823724  NetCashProvidedByUsedInInvestingActivities  1750  AAR CORP
# 16837494  NetCashProvidedByUsedInOperatingActivities  1750  AAR CORP
# 16837495  NetCashProvidedByUsedInOperatingActivities  1750  AAR CORP
# 13541780  NetCashProvidedByUsedInInvestingActivities  1750  AAR CORP
# 13541781  NetCashProvidedByUsedInInvestingActivities  1750  AAR CORP
# 13543609  NetCashProvidedByUsedInOperatingActivities  1750  AAR CORP
# 13543610  NetCashProvidedByUsedInOperatingActivities  1750  AAR CORP
# 11343607  NetCashProvidedByUsedInInvestingActivities  1750  AAR CORP
# 11343608  NetCashProvidedByUsedInInvestingActivities  1750  AAR CORP
# 11344259  NetCashProvidedByUsedInOperatingActivities  1750  AAR CORP
# 11344260  NetCashProvidedByUsedInOperatingActivities  1750  AAR CORP
# 9353014   NetCashProvidedByUsedInInvestingActivities  1750  AAR CORP
# 9353015   NetCashProvidedByUsedInInvestingActivities  1750  AAR CORP
# 9378294   NetCashProvidedByUsedInOperatingActivities  1750  AAR CORP
# 9378295   NetCashProvidedByUsedInOperatingActivities  1750  AAR CORP
# 5653118   NetCashProvidedByUsedInInvestingActivities  1750  AAR CORP
# 5653119   NetCashProvidedByUsedInInvestingActivities  1750  AAR CORP
# 5661761   NetCashProvidedByUsedInOperatingActivities  1750  AAR CORP
# 5661762   NetCashProvidedByUsedInOperatingActivities  1750  AAR CORP
# 4289476   NetCashProvidedByUsedInOperatingActivities  1750  AAR CORP
# 4289477   NetCashProvidedByUsedInOperatingActivities  1750  AAR CORP
# 4966510   NetCashProvidedByUsedInInvestingActivities  1750  AAR CORP
# 4966511   NetCashProvidedByUsedInInvestingActivities  1750  AAR CORP
# 2271485   NetCashProvidedByUsedInOperatingActivities  1750  AAR CORP
# 2271486   NetCashProvidedByUsedInOperatingActivities  1750  AAR CORP
#
#                version     ddate  qtrs  uom       value stmt  \
# 23200195  us-gaap/2016  20170228     3  USD -12800000.0   CF
# 23200196  us-gaap/2016  20180228     3  USD -37000000.0   CF
# 23205169  us-gaap/2016  20170228     3  USD -11200000.0   CF
# 23205170  us-gaap/2016  20180228     3  USD  32900000.0   CF
# 20715159  us-gaap/2018  20170831     1  USD  -6900000.0   CF
# 20715160  us-gaap/2018  20180831     1  USD  -5000000.0   CF
# 20722674  us-gaap/2018  20170831     1  USD -20600000.0   CF
# 20722675  us-gaap/2018  20180831     1  USD -27000000.0   CF
# 18751621  us-gaap/2018  20171130     2  USD -32800000.0   CF
# 18751622  us-gaap/2018  20181130     2  USD  -9400000.0   CF
# 18762830  us-gaap/2018  20171130     2  USD  -9900000.0   CF
# 18762831  us-gaap/2018  20181130     2  USD -35500000.0   CF
# 16823723  us-gaap/2018  20180228     3  USD -37000000.0   CF
# 16823724  us-gaap/2018  20190228     3  USD -13800000.0   CF
# 16837494  us-gaap/2018  20180228     3  USD  32900000.0   CF
# 16837495  us-gaap/2018  20190228     3  USD  24500000.0   CF
# 13541780  us-gaap/2019  20180831     1  USD  -5000000.0   CF
# 13541781  us-gaap/2019  20190831     1  USD  -3500000.0   CF
# 13543609  us-gaap/2019  20180831     1  USD -27000000.0   CF
# 13543610  us-gaap/2019  20190831     1  USD -32400000.0   CF
# 11343607  us-gaap/2019  20181130     2  USD  -9400000.0   CF
# 11343608  us-gaap/2019  20191130     2  USD -11700000.0   CF
# 11344259  us-gaap/2019  20181130     2  USD -35500000.0   CF
# 11344260  us-gaap/2019  20191130     2  USD -17900000.0   CF
# 9353014   us-gaap/2019  20200229     3  USD -20000000.0   CF
# 9353015   us-gaap/2019  20190228     3  USD -13800000.0   CF
# 9378294   us-gaap/2019  20200229     3  USD  -8900000.0   CF
# 9378295   us-gaap/2019  20190228     3  USD  24500000.0   CF
# 5653118   us-gaap/2019  20190831     1  USD  -3500000.0   CF
# 5653119   us-gaap/2019  20200831     1  USD  -1700000.0   CF
# 5661761   us-gaap/2019  20190831     1  USD -32400000.0   CF
# 5661762   us-gaap/2019  20200831     1  USD  38900000.0   CF
# 4289476   us-gaap/2020  20191130     2  USD -17900000.0   CF
# 4289477   us-gaap/2020  20201130     2  USD  65500000.0   CF
# 4966510   us-gaap/2020  20191130     2  USD -11700000.0   CF
# 4966511   us-gaap/2020  20201130     2  USD   5600000.0   CF
# 2271485   us-gaap/2020  20200229     3  USD  -8900000.0   CF
# 2271486   us-gaap/2020  20210228     3  USD  82600000.0   CF
#
#                                                      plabel    afs  wksi  \
# 23200195              Net cash used in investing activities  1-LAF     0
# 23200196              Net cash used in investing activities  1-LAF     0
# 23205169  Net cash provided from (used in) operating act...  1-LAF     0
# 23205170  Net cash provided from (used in) operating act...  1-LAF     0
# 20715159              Net cash used in investing activities  1-LAF     1
# 20715160              Net cash used in investing activities  1-LAF     1
# 20722674              Net cash used in operating activities  1-LAF     1
# 20722675              Net cash used in operating activities  1-LAF     1
# 18751621              Net cash used in investing activities  1-LAF     0
# 18751622              Net cash used in investing activities  1-LAF     0
# 18762830              Net cash used in operating activities  1-LAF     0
# 18762831              Net cash used in operating activities  1-LAF     0
# 16823723              Net cash used in investing activities  1-LAF     0
# 16823724              Net cash used in investing activities  1-LAF     0
# 16837494        Net cash provided from operating activities  1-LAF     0
# 16837495        Net cash provided from operating activities  1-LAF     0
# 13541780              Net cash used in investing activities  1-LAF     0
# 13541781              Net cash used in investing activities  1-LAF     0
# 13543609              Net cash used in operating activities  1-LAF     0
# 13543610              Net cash used in operating activities  1-LAF     0
# 11343607              Net cash used in investing activities  1-LAF     0
# 11343608              Net cash used in investing activities  1-LAF     0
# 11344259              Net cash used in operating activities  1-LAF     0
# 11344260              Net cash used in operating activities  1-LAF     0
# 9353014               Net cash used in investing activities  1-LAF     0
# 9353015               Net cash used in investing activities  1-LAF     0
# 9378294   Net cash provided from (used in) operating act...  1-LAF     0
# 9378295   Net cash provided from (used in) operating act...  1-LAF     0
# 5653118               Net cash used in investing activities  1-LAF     0
# 5653119               Net cash used in investing activities  1-LAF     0
# 5661761   Net cash provided from (used in) operating act...  1-LAF     0
# 5661762   Net cash provided from (used in) operating act...  1-LAF     0
# 4289476   Net cash provided from (used in) operating act...  1-LAF     0
# 4289477   Net cash provided from (used in) operating act...  1-LAF     0
# 4966510               Net cash used in investing activities  1-LAF     0
# 4966511               Net cash used in investing activities  1-LAF     0
# 2271485   Net cash provided from (used in) operating act...  1-LAF     0
# 2271486   Net cash provided from (used in) operating act...  1-LAF     0
#
#             fye      period      fy  fp
# 23200195  531.0  20180228.0  2018.0  Q3
# 23200196  531.0  20180228.0  2018.0  Q3
# 23205169  531.0  20180228.0  2018.0  Q3
# 23205170  531.0  20180228.0  2018.0  Q3
# 20715159  531.0  20180831.0  2019.0  Q1
# 20715160  531.0  20180831.0  2019.0  Q1
# 20722674  531.0  20180831.0  2019.0  Q1
# 20722675  531.0  20180831.0  2019.0  Q1
# 18751621  531.0  20181130.0  2019.0  Q2
# 18751622  531.0  20181130.0  2019.0  Q2
# 18762830  531.0  20181130.0  2019.0  Q2
# 18762831  531.0  20181130.0  2019.0  Q2
# 16823723  531.0  20190228.0  2019.0  Q3
# 16823724  531.0  20190228.0  2019.0  Q3
# 16837494  531.0  20190228.0  2019.0  Q3
# 16837495  531.0  20190228.0  2019.0  Q3
# 13541780  531.0  20190831.0  2020.0  Q1
# 13541781  531.0  20190831.0  2020.0  Q1
# 13543609  531.0  20190831.0  2020.0  Q1
# 13543610  531.0  20190831.0  2020.0  Q1
# 11343607  531.0  20191130.0  2020.0  Q2
# 11343608  531.0  20191130.0  2020.0  Q2
# 11344259  531.0  20191130.0  2020.0  Q2
# 11344260  531.0  20191130.0  2020.0  Q2
# 9353014   531.0  20200229.0  2020.0  Q3
# 9353015   531.0  20200229.0  2020.0  Q3
# 9378294   531.0  20200229.0  2020.0  Q3
# 9378295   531.0  20200229.0  2020.0  Q3
# 5653118   531.0  20200831.0  2021.0  Q1
# 5653119   531.0  20200831.0  2021.0  Q1
# 5661761   531.0  20200831.0  2021.0  Q1
# 5661762   531.0  20200831.0  2021.0  Q1
# 4289476   531.0  20201130.0  2021.0  Q2
# 4289477   531.0  20201130.0  2021.0  Q2
# 4966510   531.0  20201130.0  2021.0  Q2
# 4966511   531.0  20201130.0  2021.0  Q2
# 2271485   531.0  20210228.0  2021.0  Q3
# 2271486   531.0  20210228.0  2021.0  Q3
