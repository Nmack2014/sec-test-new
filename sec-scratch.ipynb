# %%
import pandas as pd

# %%
tags_df = pd.read_csv("tag.txt", sep='\t')
nums_df = pd.read_csv("num.txt", sep='\t')
pres_df = pd.read_csv("pre.txt", sep='\t')
subs_df = pd.read_csv("sub.txt", sep='\t')

# %%
tags_df
# Out:
#                                                       tag  \
# 0                                                      PA
# 1                                                      MA
# 2                                                      NC
# 3                                                      CA
# 4                                                      GA
# ...                                                   ...
# 118123                 SharesIssuedOnAcquisitionOfSignifi
# 118124  TradeAndOtherReceivablesPrepaidsAndAdvancesToS...
# 118125                             TransactionCostsNote22
# 118126                              TranslationAdjustment
# 118127                               WeightedAverageShare
#
#                      version  custom  abstract  datatype iord crdr  \
# 0                  stpr/2018       0         1    member  NaN  NaN
# 1                  stpr/2018       0         1    member  NaN  NaN
# ...

# %%
nums_df
# Out:
#                          adsh                                          tag  \
# 0        0001640334-21-000798  AccountsPayableAndAccruedLiabilitiesCurrent
# 1        0001640334-21-000798  AccountsPayableAndAccruedLiabilitiesCurrent
# 2        0001477932-21-002126  AccountsPayableAndAccruedLiabilitiesCurrent
# 3        0001477932-21-002126  AccountsPayableAndAccruedLiabilitiesCurrent
# 4        0001640334-21-000810  AccountsPayableAndAccruedLiabilitiesCurrent
# ...                       ...                                          ...
# 2441785  0001213900-21-035102                      WarrantExercisablePrice
# 2441786  0001213900-21-035102                                WarrantsIssue
# 2441787  0001213900-21-035102                         WeightedAverageShare
# 2441788  0001213900-21-035102                         WeightedAverageShare
# 2441789  0001213900-21-035102                         WeightedAverageShare
#
# ...

# %%
pres_df
# Out:
#                          adsh  report  line stmt  inpth rfile  \
# 0        0001437749-21-011167       1     3   CP      0     H
# 1        0001109357-21-000050       1     4   CP      0     H
# 2        0001109357-21-000050       1     6   CP      0     H
# 3        0001109357-21-000050       1     5   CP      0     H
# 4        0001165002-21-000044       2    21   BS      0     H
# ...                       ...     ...   ...  ...    ...   ...
# 1311072  0001628280-21-013239       6    28   CF      0     H
# 1311073  0001628280-21-013239       5    21   EQ      0     H
# 1311074  0001628280-21-013239       5    22   EQ      0     H
# 1311075  0001628280-21-013239       3     8   BS      1     H
# 1311076  0001628280-21-013239       6    32   CF      0     H
#
#                                                        tag  \
# 0                                                       AL
# 1                                                       DC
# ...

# %%
subs_df
# Out:
#                        adsh      cik                                     name  \
# 0      0000009389-21-000078     9389                                BALL CORP
# 1      0000037996-21-000020    37996                            FORD MOTOR CO
# 2      0000038009-21-000033    38009                 FORD MOTOR CREDIT CO LLC
# 3      0000038725-21-000080    38725                 FRANKLIN ELECTRIC CO INC
# 4      0000048732-21-000004    48732  CENTERPOINT ENERGY HOUSTON ELECTRIC LLC
# ...                     ...      ...                                      ...
# 20689  0001731122-21-001110  1698832           WALL STREET ACQUISITIONS, CORP
# 20690  0001745797-21-000044  1745797                   BRIGHAM MINERALS, INC.
# 20691  0001759655-21-000017  1759655                PRIVIA HEALTH GROUP, INC.
# 20692  0001818874-21-000016  1818874                  SOFI TECHNOLOGIES, INC.
# 20693  0001831631-21-000063  1831631                          LOANDEPOT, INC.
#
# ...

# %%
num_sub=pd.merge(nums_df,subs_df,how='left',on='adsh')

# %%
num_sub.form.unique()
# Out:
# array(['10-Q', '10-K', 'POS AM', 'S-1/A', '10-Q/A', '10-K/A', 'S-1',
#        '20-F', 'S-4', '6-K', '10-KT', '40-F/A', '20-F/A', '40-F', '6-K/A',
#        '8-K', 'S-4/A', 'S-11/A', '10-12G/A', 'S-11', 'SP 15D2', 'F-1',
#        '8-K/A', 'F-1/A', '10-QT', 'F-4', '10-12G'], dtype=object)

# %%
num_sub_df=num_sub[(num_sub['form']=='10-Q')]

# %%
num_sub_df
# Out:
#                          adsh  \
# 2        0001477932-21-002126
# 3        0001477932-21-002126
# 10       0001640334-21-000808
# 11       0001640334-21-000808
# 18       0001640334-21-000838
# ...                       ...
# 2441336  0001193125-21-204830
# 2441337  0001193125-21-204830
# 2441338  0001193125-21-204830
# 2441339  0001193125-21-204830
# 2441340  0001193125-21-204830
#
#                                                        tag  \
# 2              AccountsPayableAndAccruedLiabilitiesCurrent
# 3              AccountsPayableAndAccruedLiabilitiesCurrent
# 10             AccountsPayableAndAccruedLiabilitiesCurrent
# 11             AccountsPayableAndAccruedLiabilitiesCurrent
# 18             AccountsPayableAndAccruedLiabilitiesCurrent
# ...                                                    ...
# 2441336           Proceedsfromredeemableinterestinvestment
# 2441337  RestructuringChargesReversalIncludingRestructu...
# ...

# %%
num_sub_df.columns
# Out:
# Index(['adsh', 'tag', 'version', 'coreg', 'ddate', 'qtrs', 'uom', 'value',
#        'footnote', 'cik', 'name', 'sic', 'countryba', 'stprba', 'cityba',
#        'zipba', 'bas1', 'bas2', 'baph', 'countryma', 'stprma', 'cityma',
#        'zipma', 'mas1', 'mas2', 'countryinc', 'stprinc', 'ein', 'former',
#        'changed', 'afs', 'wksi', 'fye', 'form', 'period', 'fy', 'fp', 'filed',
#        'accepted', 'prevrpt', 'detail', 'instance', 'nciks', 'aciks'],
#       dtype='object')

# %%
num_sub_df=num_sub_df[['adsh', 'form', 'tag', 'cik', 'name', 'version', 'ddate', 'qtrs', 'uom', 'value',
       'sic', 'ein', 'former', 'changed', 'afs', 'wksi', 'fye', 'period', 'fy', 'fp']]

# %%
num_sub_df
# Out:
#                          adsh  form  \
# 0        0001640334-21-000798  10-Q
# 1        0001640334-21-000798  10-Q
# 4        0001640334-21-000810  10-Q
# 5        0001640334-21-000810  10-Q
# 8        0001477932-21-002141  10-Q
# ...                       ...   ...
# 2441012  0000796343-21-000159  10-Q
# 2441013  0000796343-21-000159  10-Q
# 2441014  0000796343-21-000159  10-Q
# 2441015  0000796343-21-000159  10-Q
# 2441016  0000796343-21-000159  10-Q
#
#                                                        tag      cik  \
# 0              AccountsPayableAndAccruedLiabilitiesCurrent  1593204
# 1              AccountsPayableAndAccruedLiabilitiesCurrent  1593204
# 4              AccountsPayableAndAccruedLiabilitiesCurrent  1584480
# 5              AccountsPayableAndAccruedLiabilitiesCurrent  1584480
# 8              AccountsPayableAndAccruedLiabilitiesCurrent  1631463
# ...                                                    ...      ...
# ...
